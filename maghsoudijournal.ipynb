# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the code smells and their refactored examples
code_smells = [
    "Data Clumps", "Feature Envy", "God object", "Inappropriate Intimacy",
    "Long Method", "Primitive Obsession", "Shotgun Surgery", "Switch Statements"
]

# Execution times for each code smell and its refactored example
iterations = [1, 10, 100, 1000, 10000, 100000]
data_clumps = [0.010, 0.040, 0.153, 0.665, 1.249, 3.130]
data_clumps_refactored = [0.021, 0.045, 0.174, 0.624, 3.332, 6.481]

feature_envy = [0.022, 0.015, 0.130, 0.334, 1.528, 4.493]
feature_envy_refactored = [0.027, 0.014, 0.128, 0.348, 1.446, 4.375]

god_object = [0.0, 0.003, 0.027, 0.088, 0.247, 0.475]
god_object_refactored = [0.0, 0.005, 0.050, 0.059, 0.290, 0.501]

inappropriate_intimacy = [0.021, 0.016, 0.124, 0.292, 1.019, 2.111]
inappropriate_intimacy_refactored = [0.260, 0.019, 0.095, 0.322, 1.209, 2.520]

long_method = [0.002, 0.002, 0.022, 0.060, 0.211, 0.736]
long_method_refactored = [0.001, 0.001, 0.009, 0.041, 0.261, 0.837]

primitive_obsession = [0.002, 0.002, 0.030, 0.069, 0.230, 0.548]
primitive_obsession_refactored = [0.003, 0.003, 0.023, 0.062, 0.224, 0.466]

shotgun_surgery = [0.000, 0.000, 0.001, 0.009, 0.088, 0.296]
shotgun_surgery_refactored = [0.004, 0.004, 0.040, 0.160, 1.047, 2.586]

switch_statements = [0.001, 0.001, 0.007, 0.067, 0.609, 1.677]
switch_statements_refactored = [0.003, 0.001, 0.011, 0.054, 0.527, 1.027]

# Set up the plotting
fig, axes = plt.subplots(4, 2, figsize=(12, 16))

# List of all the code smells and refactored versions for plotting
data = [
    (data_clumps, data_clumps_refactored, "Data Clumps"),
    (feature_envy, feature_envy_refactored, "Feature Envy"),
    (god_object, god_object_refactored, "God Object"),
    (inappropriate_intimacy, inappropriate_intimacy_refactored, "Inappropriate Intimacy"),
    (long_method, long_method_refactored, "Long Method"),
    (primitive_obsession, primitive_obsession_refactored, "Primitive Obsession"),
    (shotgun_surgery, shotgun_surgery_refactored, "Shotgun Surgery"),
    (switch_statements, switch_statements_refactored, "Switch Statements")
]

# Plot each pair of data
for ax, (example, refactored, smell_name) in zip(axes.flatten(), data):
    ax.plot(iterations, example, label=f"Original {smell_name}", color='blue', marker='o')
    ax.plot(iterations, refactored, label=f"Refactored {smell_name}", color='green', marker='x')

    ax.set_title(f"{smell_name} Execution Time Comparison")
    ax.set_xlabel("Iterations")
    ax.set_ylabel("Execution Time (milliseconds)")
    ax.legend()
    ax.grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the code smells and their refactored examples (energy consumption)
code_smells = [
    "Data Clumps", "Feature Envy", "God object", "Inappropriate Intimacy",
    "Long Method", "Primitive Obsession", "Shotgun Surgery", "Switch Statements"
]

# Energy consumption for each code smell and its refactored example
iterations = np.array([1, 10, 100, 1000, 10000, 100000])
data_clumps = [0.87, 1.03, 0.98, 0.72, 2.68, 14.76]
data_clumps_refactored = [1.05, 0.89, 0.89, 0.83, 2.94, 16.28]

feature_envy = [0.798, 1.082, 0.988, 1.162, 3.752, 19.424]
feature_envy_refactored = [0.81, 1.216, 1.074, 1.214, 3.964, 20.154]

god_object = [1.05, 0.93, 0.62, 0.84, 2.77, 15.62]
god_object_refactored = [0.68, 0.69, 0.84, 0.8, 3.48, 26.41]

inappropriate_intimacy = [0.79, 1.08, 0.98, 1.16, 3.75, 19.42]
inappropriate_intimacy_refactored = [0.81, 1.21, 1.07, 1.21, 3.96, 20.15]

long_method = [1.1, 1.31, 1.38, 1.18, 6.07, 33.8]
long_method_refactored = [0.69, 0.96, 1.05, 1.55, 4.93, 72.54]

primitive_obsession = [1.41, 1.77, 1.74, 1.77, 5.56, 17.53]
primitive_obsession_refactored = [1.24, 0.73, 1.1, 0.98, 4.55, 14.43]

shotgun_surgery = [1.23, 1.03, 1.15, 0.81, 3.53, 18.05]
shotgun_surgery_refactored = [1.23, 1.15, 1.14, 0.87, 2.75, 18.49]

switch_statements = [0.7, 0.82, 0.92, 1.06, 3.03, 13.98]
switch_statements_refactored = [0.61, 0.69, 0.81, 0.94, 2.86, 12.7]

# Set up the plotting
fig, axes = plt.subplots(4, 2, figsize=(12, 16))

# List of all the code smells and refactored versions for plotting
data = [
    (data_clumps, data_clumps_refactored, "Data Clumps"),
    (feature_envy, feature_envy_refactored, "Feature Envy"),
    (god_object, god_object_refactored, "God Object"),
    (inappropriate_intimacy, inappropriate_intimacy_refactored, "Inappropriate Intimacy"),
    (long_method, long_method_refactored, "Long Method"),
    (primitive_obsession, primitive_obsession_refactored, "Primitive Obsession"),
    (shotgun_surgery, shotgun_surgery_refactored, "Shotgun Surgery"),
    (switch_statements, switch_statements_refactored, "Switch Statements")
]

# Plot each pair of data
for ax, (example, refactored, smell_name) in zip(axes.flatten(), data):
    ax.plot(iterations, example, label=f"Original {smell_name}", color='blue', marker='o')
    ax.plot(iterations, refactored, label=f"Refactored {smell_name}", color='green', marker='x')

    ax.set_title(f"{smell_name} Energy Consumption Comparison")
    ax.set_xlabel("Iterations")  # Iteration numbers will now appear clearly
    ax.set_ylabel("Energy Consumption (joules)")  # Show energy consumption in the Y-axis
    ax.set_xscale('log')  # Set logarithmic scale for better visibility of large range of iterations
    ax.legend()
    ax.grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the code smells and their refactored examples (execution times)
code_smells = [
    "Data Clumps", "Feature Envy", "God object", "Inappropriate Intimacy",
    "Long Method", "Primitive Obsession", "Shotgun Surgery", "Switch Statements"
]

# Execution times for each code smell and its refactored example
iterations = np.array([1, 10, 100, 1000, 10000, 100000])
data_clumps = [0.010, 0.040, 0.153, 0.665, 1.249, 3.130]
data_clumps_refactored = [0.021, 0.045, 0.174, 0.624, 3.332, 6.481]

feature_envy = [0.022, 0.015, 0.130, 0.334, 1.528, 4.493]
feature_envy_refactored = [0.027, 0.014, 0.128, 0.348, 1.446, 4.375]

god_object = [0.003, 0.003, 0.027, 0.088, 0.247, 0.475]
god_object_refactored = [0.005, 0.005, 0.050, 0.059, 0.290, 0.501]

inappropriate_intimacy = [0.016, 0.016, 0.124, 0.292, 1.019, 2.111]
inappropriate_intimacy_refactored = [0.019, 0.019, 0.095, 0.322, 1.209, 2.520]

long_method = [0.002, 0.002, 0.022, 0.060, 0.211, 0.736]
long_method_refactored = [0.001, 0.001, 0.009, 0.041, 0.261, 0.837]

primitive_obsession = [0.002, 0.001, 0.030, 0.069, 0.230, 0.548]
primitive_obsession_refactored = [0.003, 0.003, 0.023, 0.062, 0.224, 0.466]

shotgun_surgery = [0.000, 0.000, 0.001, 0.009, 0.088, 0.296]
shotgun_surgery_refactored = [0.004, 0.004, 0.040, 0.160, 1.047, 2.586]

switch_statements = [0.001, 0.001, 0.007, 0.067, 0.609, 1.677]
switch_statements_refactored = [0.003, 0.001, 0.011, 0.054, 0.527, 1.027]

# Set up the plotting
fig, axes = plt.subplots(4, 2, figsize=(12, 16))

# List of all the code smells and refactored versions for plotting
data = [
    (data_clumps, data_clumps_refactored, "Data Clumps"),
    (feature_envy, feature_envy_refactored, "Feature Envy"),
    (god_object, god_object_refactored, "God Object"),
    (inappropriate_intimacy, inappropriate_intimacy_refactored, "Inappropriate Intimacy"),
    (long_method, long_method_refactored, "Long Method"),
    (primitive_obsession, primitive_obsession_refactored, "Primitive Obsession"),
    (shotgun_surgery, shotgun_surgery_refactored, "Shotgun Surgery"),
    (switch_statements, switch_statements_refactored, "Switch Statements")
]

# Plot each pair of data
for ax, (example, refactored, smell_name) in zip(axes.flatten(), data):
    ax.plot(iterations, example, label=f"Original {smell_name}", color='blue', marker='o')
    ax.plot(iterations, refactored, label=f"Refactored {smell_name}", color='green', marker='x')

    ax.set_title(f"{smell_name} Execution Time Comparison")
    ax.set_xlabel("Iterations")  # Iteration numbers will now appear clearly
    ax.set_ylabel("Execution Time (seconds)")  # Show execution time in seconds in the Y-axis
    ax.set_xscale('log')  # Set logarithmic scale for better visibility of large range of iterations
    ax.legend()
    ax.grid(True)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
